# %%
#tworzenie funkcji poprzez dlowo kluczowe def, nazwe funkcji i ()

# %%
def dodaj():
    x= 2+2+2+3
    return x

# %%
# wowołanie poprzez nazwe z () jesli byl return mozna przypisac  to co w return do innej zmiennej

# %%
suma = dodaj()

# %%
suma
# Out:
# 9
